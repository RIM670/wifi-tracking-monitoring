# %%
from math import pow
import subprocess
import re
import matplotlib.pyplot as plt

def read_data_from_cmd():
    p = subprocess.Popen("netsh wlan show networks mode=bssid", stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    out = p.stdout.read().decode('unicode_escape').strip()
    p.communicate() 
    return out

def get_signal_strength(SSID):
    data = read_data_from_cmd()
    print("Networks found:\n", data)  # Debugging: print all network data
    list1 = re.findall(r'SSID \d+ : (.*?)\n.*?Signal\s+:\s+(\d+)%', data, re.DOTALL)
    
    for i in list1:
        if i[0].strip() == SSID:
            return int(i[1])  # Return signal strength as integer
    return None

def calculate_distance_wifi(signal_strength):
    if signal_strength <= 0:
        rssi = -100
    elif signal_strength >= 100:
        rssi = -50
    else:
        rssi = signal_strength / 2 - 100

    measured_power = -45  # Reference power level at 1 meter
    n = 2.5               # Path-loss exponent

    distance = pow(10, (measured_power - rssi) / (10 * n))
    return distance

# Define SSIDs and positions of the access points
access_points = {
    'AP1': {'ssid': 'Ooredoo 4G_8A7073', 'position': (0, 0)},
    'AP2': {'ssid': 'Rouee', 'position': (10, 0)},
    'AP3': {'ssid': 'Iphone', 'position': (5, 8.66)}  # Roughly an equilateral triangle
}

distances = {}

# Calculate distances for each access point
for ap, info in access_points.items():
    ssid = info['ssid']
    signal_strength = get_signal_strength(ssid)
    if signal_strength is not None:
        distance = calculate_distance_wifi(signal_strength)
        distances[ap] = distance
        print(f"Estimated distance to {ssid}: {distance:.2f} meters")
    else:
        print(f"SSID '{ssid}' not found.")

# Initialize plot
fig, ax = plt.subplots()

# Define unique colors for each AP circle
colors = ['blue', 'green', 'red']

# Draw circles for each AP based on the calculated distances
for i, (ap, info) in enumerate(access_points.items()):
    x, y = info['position']
    distance = distances.get(ap, 0)
    
    # Draw the circle with unique color, larger size, and thicker line
    circle = plt.Circle((x, y), distance, color=colors[i], alpha=0.3, fill=False, linestyle='--', linewidth=2)
    ax.add_artist(circle)
    
    # Mark the position of the access point and label it
    ax.plot(x, y, 'o', color=colors[i])  # Change marker color to match circle
    ax.text(x, y, f'{ap}', ha='center', va='center', color=colors[i], fontweight='bold')

# Set plot limits and labels for visibility
ax.set_xlim(-5, 15)
ax.set_ylim(-5, 15)
plt.xlabel("X (meters)")
plt.ylabel("Y (meters)")
plt.title("Triangulation Based on RSSI Values")
plt.gca().set_aspect('equal', adjustable='box')

# Display the plot
plt.show()
# Out:
# Networks found:
#  Interface name : Wi-Fi
# There are 19 networks currently visible.
#
# SSID 1 : Ooredoo 4G_8A7073
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : d4:72:26:8a:70:73
#          Signal             : 99%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 2 : Galaxy A02s
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 42:93:23:7a:68:f6
#          Signal             : 78%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 2
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 3 : Airbox-C5DE
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 54:1f:8d:cb:c5:de
#          Signal             : 70%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 4 : Sahar
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 3a:8e:23:47:ce:a2
#          Signal             : 90%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 5 : DESKTOP-MONIKA
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 4e:82:a9:00:2f:b3
#          Signal             : 65%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 6 12 24
#          Other rates (Mbps) : 9 18 36 48 54
#
# SSID 6 : Redmi Note 9S
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : ca:46:5e:ff:06:91
#          Signal             : 29%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 7 : Yassine
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : f2:79:9c:9c:e7:13
#          Signal             : 46%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 8 : Redminote8
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : d2:36:46:fa:b7:e0
#          Signal             : 82%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 9 : Bochboch
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 86:45:7c:97:58:a7
#          Signal             : 86%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 10 : Airbox-A4C4
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : f0:51:36:92:a4:c4
#          Signal             : 53%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 11 : Joumana
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 0a:8e:26:26:83:e5
#          Signal             : 83%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 12 : Rouee
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 2e:1b:11:74:63:54
#          Signal             : 88%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 13 : Iphone
#     Network type            : Infrastructure
#     Authentication          : WPA3-Personal
#     Encryption              : CCMP
#     BSSID 1                 : be:4c:48:ea:92:b1
#          Signal             : 81%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 6
#          Hash-to-Element:   : Not supported
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 14 : OPPO A54
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : da:68:6e:9c:f8:46
#          Signal             : 83%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 15 : Galaxy Note10 Litee65c
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 66:16:ff:b3:9f:a9
#          Signal             : 90%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 16 :  AP2_Seki
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 32:ac:b2:a9:79:1f
#          Signal             : 82%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 17 : Airbox-EA3D
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 70:4d:e7:2b:ea:3d
#          Signal             : 85%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 18 : Galaxy123
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 4a:af:b8:62:8b:c3
#          Signal             : 86%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 19 : Fuck off
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 0e:91:19:f7:64:b7
#          Signal             : 72%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
# Estimated distance to Ooredoo 4G_8A7073: 1.66 meters
# Networks found:
#  Interface name : Wi-Fi
# There are 19 networks currently visible.
#
# SSID 1 : Ooredoo 4G_8A7073
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : d4:72:26:8a:70:73
#          Signal             : 99%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 2 : Galaxy A02s
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 42:93:23:7a:68:f6
#          Signal             : 78%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 2
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 3 : Airbox-C5DE
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 54:1f:8d:cb:c5:de
#          Signal             : 70%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 4 : Sahar
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 3a:8e:23:47:ce:a2
#          Signal             : 90%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 5 : DESKTOP-MONIKA
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 4e:82:a9:00:2f:b3
#          Signal             : 65%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 6 12 24
#          Other rates (Mbps) : 9 18 36 48 54
#
# SSID 6 : Redmi Note 9S
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : ca:46:5e:ff:06:91
#          Signal             : 29%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 7 : Yassine
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : f2:79:9c:9c:e7:13
#          Signal             : 46%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 8 : Redminote8
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : d2:36:46:fa:b7:e0
#          Signal             : 82%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 9 : Bochboch
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 86:45:7c:97:58:a7
#          Signal             : 86%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 10 : Airbox-A4C4
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : f0:51:36:92:a4:c4
#          Signal             : 53%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 11 : Joumana
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 0a:8e:26:26:83:e5
#          Signal             : 83%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 12 : Rouee
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 2e:1b:11:74:63:54
#          Signal             : 88%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 13 : Iphone
#     Network type            : Infrastructure
#     Authentication          : WPA3-Personal
#     Encryption              : CCMP
#     BSSID 1                 : be:4c:48:ea:92:b1
#          Signal             : 81%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 6
#          Hash-to-Element:   : Not supported
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 14 : OPPO A54
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : da:68:6e:9c:f8:46
#          Signal             : 83%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 15 : Galaxy Note10 Litee65c
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 66:16:ff:b3:9f:a9
#          Signal             : 90%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 16 :  AP2_Seki
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 32:ac:b2:a9:79:1f
#          Signal             : 82%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 17 : Airbox-EA3D
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 70:4d:e7:2b:ea:3d
#          Signal             : 85%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 18 : Galaxy123
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 4a:af:b8:62:8b:c3
#          Signal             : 86%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 19 : Fuck off
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 0e:91:19:f7:64:b7
#          Signal             : 72%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
# Estimated distance to Rouee: 2.75 meters
# Networks found:
#  Interface name : Wi-Fi
# There are 19 networks currently visible.
#
# SSID 1 : Ooredoo 4G_8A7073
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : d4:72:26:8a:70:73
#          Signal             : 99%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 2 : Galaxy A02s
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 42:93:23:7a:68:f6
#          Signal             : 78%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 2
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 3 : Airbox-C5DE
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 54:1f:8d:cb:c5:de
#          Signal             : 70%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 4 : Sahar
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 3a:8e:23:47:ce:a2
#          Signal             : 90%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 5 : DESKTOP-MONIKA
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 4e:82:a9:00:2f:b3
#          Signal             : 65%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 6 12 24
#          Other rates (Mbps) : 9 18 36 48 54
#
# SSID 6 : Redmi Note 9S
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : ca:46:5e:ff:06:91
#          Signal             : 29%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 7 : Yassine
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : f2:79:9c:9c:e7:13
#          Signal             : 46%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 8 : Redminote8
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : d2:36:46:fa:b7:e0
#          Signal             : 82%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 9 : Bochboch
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 86:45:7c:97:58:a7
#          Signal             : 86%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 10 : Airbox-A4C4
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : f0:51:36:92:a4:c4
#          Signal             : 53%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 11 : Joumana
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 0a:8e:26:26:83:e5
#          Signal             : 83%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 12 : Rouee
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 2e:1b:11:74:63:54
#          Signal             : 88%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 13 : Iphone
#     Network type            : Infrastructure
#     Authentication          : WPA3-Personal
#     Encryption              : CCMP
#     BSSID 1                 : be:4c:48:ea:92:b1
#          Signal             : 81%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 6
#          Hash-to-Element:   : Not supported
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 14 : OPPO A54
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : da:68:6e:9c:f8:46
#          Signal             : 83%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 15 : Galaxy Note10 Litee65c
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 66:16:ff:b3:9f:a9
#          Signal             : 90%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 16 :  AP2_Seki
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 32:ac:b2:a9:79:1f
#          Signal             : 82%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 17 : Airbox-EA3D
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 70:4d:e7:2b:ea:3d
#          Signal             : 85%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 11
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 18 : Galaxy123
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 4a:af:b8:62:8b:c3
#          Signal             : 86%
#          Radio type         : 802.11ac
#          Band               : 2.4 GHz
#          Channel            : 6
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
#
# SSID 19 : Fuck off
#     Network type            : Infrastructure
#     Authentication          : WPA2-Personal
#     Encryption              : CCMP
#     BSSID 1                 : 0e:91:19:f7:64:b7
#          Signal             : 72%
#          Radio type         : 802.11n
#          Band               : 2.4 GHz
#          Channel            : 1
#          Basic rates (Mbps) : 1 2 5.5 11
#          Other rates (Mbps) : 6 9 12 18 24 36 48 54
# Estimated distance to Iphone: 3.80 meters
